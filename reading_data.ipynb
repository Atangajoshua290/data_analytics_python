# %% [markdown]
# # importing librareis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # loading Dataset

# %%
#the data preview  is call data frame
#loading an csv data file
iris_data = pd.read_csv("Datasets/Iris_data_sample.csv")
iris_data
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
#loading an excel data file

iris_data2 = pd.read_excel("Datasets/Iris_data_sample.xlsx")

iris_data2
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
#loading txt data file

Iris_data_txt=pd.read_table("Datasets/Iris_data_sample.txt", delimiter=" ")
Iris_data_txt
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
# copying data
#shallow copying
df_1=Iris_data_txt.copy(deep=False)
df_1
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
#deep copying
df_2 = iris_data.copy(deep = True)
df_2
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
#deleting a column from a data set

del df_2["Unnamed: 0"]
df_2
# Out:
#     SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm         Species
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           NaN           1.4           0.2             NaN
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3              ??           3.1           1.5           0.2     Iris-setosa
# 4               5           3.6           ###           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5             5           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#deep copying

df_3 = Iris_data_txt.copy()

df_3
# Out:
#      Unnamed: 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1             1            5.1           3.5            1.4           0.2
# 2             2            4.9           3.0            1.4           0.2
# 3             3            4.7           3.2            1.3           0.2
# 4             4            4.6           3.1            1.5           0.2
# 5             5            5.0           3.6            1.4           0.2
# ..          ...            ...           ...            ...           ...
# 146         146            6.7           3.0            5.2           2.3
# 147         147            6.3           2.5            5.0           1.9
# 148         148            6.5           3.0            5.2           2.0
# 149         149            6.2           3.4            5.4           2.3
# 150         150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %% [markdown]
# # data overview
# index,
# columns,
# size,
# shape

# %%
df_2.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# the number of columns
df_2.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#size of the data
df_2.size
# Out:
# 750

# %%
# shape shows the number of rows and columns in the data set
df_2.shape
# Out:
# (150, 5)

# %% [markdown]
# # indexing and selecting
# . head() first five rows
# . tail() last five five rows

# %%
df_2.head()
# Out:
#   SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm      Species
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           NaN           1.4           0.2          NaN
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3            ??           3.1           1.5           0.2  Iris-setosa
# 4             5           3.6           ###           0.2  Iris-setosa

# %%
df_2.tail()
# Out:
#     SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm         Species
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5             5           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica

# %% [markdown]
# # specifying the number of rows

# %%
df_2.head(10)
# Out:
#   SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm      Species
# 0           5.1           3.5           1.4           0.2  Iris-setosa
# 1           4.9           NaN           1.4           0.2          NaN
# 2           4.7           3.2           1.3           0.2  Iris-setosa
# 3            ??           3.1           1.5           0.2  Iris-setosa
# 4             5           3.6           ###           0.2  Iris-setosa
# 5           5.4           3.9           NaN           0.4  Iris-setosa
# 6           4.6           3.4           1.4           0.3  Iris-setosa
# 7             5           3.4           1.5           0.2  Iris-setosa
# 8           4.4           2.9           1.4           0.2  Iris-setosa
# 9           4.9           3.1           1.5           0.1  Iris-setosa

# %%
df_2.tail(10)
# Out:
#     SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm         Species
# 140           6.7           3.1           5.6           2.4  Iris-virginica
# 141           6.9           3.1           5.1           2.3  Iris-virginica
# 142           5.8           2.7           5.1           1.9  Iris-virginica
# 143           6.8           3.2           5.9           2.3  Iris-virginica
# 144           6.7           3.3           5.7           2.5  Iris-virginica
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5             5           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica

# %%
# geting a specific data using the (at) function

df_2.at[2, "SepalLengthCm"]
# Out:
# '4.7'

# %%
# # geting a specific data using the (iat) function

df_2.iat[2,1]
# Out:
# 3.2

# %%
# selecting data from a particular column using (loc)

df_2.loc[:, "Species"]
# Out:
# 0         Iris-setosa
# 1                 NaN
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
# specifying 

df_2.loc[10:30,"Species"]
# Out:
# 10    Iris-setosa
# 11    Iris-setosa
# 12    Iris-setosa
# 13    Iris-setosa
# 14    Iris-setosa
# 15    Iris-setosa
# 16    Iris-setosa
# 17    Iris-setosa
# 18    Iris-setosa
# 19    Iris-setosa
# 20    Iris-setosa
# 21    Iris-setosa
# 22    Iris-setosa
# 23    Iris-setosa
# 24    Iris-setosa
# 25    Iris-setosa
# 26    Iris-setosa
# 27    Iris-setosa
# 28    Iris-setosa
# 29    Iris-setosa
# 30    Iris-setosa
# Name: Species, dtype: object

# %%
#toyota  dataset
toyota= pd.read_csv("Datasets/Toyota.csv")
toyota
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df=toyota.copy()
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
#Deleting a column in a dataframe

del df["Unnamed: 0"]

# %%
df
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
df.shape
# Out:
# (1436, 10)

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df.size
# Out:
# 14360

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
# checking the type of each colun

df.dtypes
# Out:
# Price          int64
# Age          float64
# KM            object
# FuelType      object
# HP            object
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
# select a section of the data base on the type
df.select_dtypes(exclude=[object])
# Out:
#       Price   Age  MetColor  Automatic    CC  Weight
# 0     13500  23.0       1.0          0  2000    1165
# 1     13750  23.0       1.0          0  2000    1165
# 2     13950  24.0       NaN          0  2000    1165
# 3     14950  26.0       0.0          0  2000    1165
# 4     13750  30.0       0.0          0  2000    1170
# ...     ...   ...       ...        ...   ...     ...
# 1431   7500   NaN       1.0          0  1300    1025
# 1432  10845  72.0       0.0          0  1300    1015
# 1433   8500   NaN       0.0          0  1300    1015
# 1434   7250  70.0       1.0          0  1300    1015
# 1435   6950  76.0       0.0          0  1600    1114
#
# [1436 rows x 6 columns]

# %%
# get concise summary of our dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 112.3+ KB

# %%
# checking for unique instance in a particular column
print(np.unique(df["KM"]))
# Out:
# ['1' '10000' '100123' ... '99865' '99971' '??']

# %%
print(np.unique(df["HP"]))
# Out:
# ['107' '110' '116' '192' '69' '71' '72' '73' '86' '90' '97' '98' '????']

# %%
print(np.unique(df["Automatic"]))
# Out:
# [0 1]

# %%
print(np.unique(df["Doors"]))
# Out:
# ['2' '3' '4' '5' 'five' 'four' 'three']

# %%
print(np.unique(df["MetColor"]))
# Out:
# [ 0.  1. nan]

# %% [markdown]
# # data preprocessing
# . prelacing (?, np.nan
# = change column type to integer

# %%
df["KM"].replace('??', np.nan)
# Out:
# 0       46986
# 1       72937
# 2       41711
# 3       48000
# 4       38500
#         ...
# 1431    20544
# 1432      NaN
# 1433    17016
# 1434      NaN
# 1435        1
# Name: KM, Length: 1436, dtype: object

# %%
#second method

df["KM"] =df["KM"].replace('??', np.nan)

# %%
df["KM"] =df["KM"].astype(float)

# %%
print(np.unique(df["KM"]))
# Out:
# [1.0000e+00 1.5000e+01 2.2500e+02 ... 2.3294e+05 2.4300e+05        nan]

# %%
#replacing the missing values

# %%
df["Doors"] =df["Doors"].replace('five', 5)

# %%
df["Doors"] =df["Doors"].replace('four', 4)

# %%
df["Doors"] =df["Doors"].replace('three', 3)

# %%
#computing the mean on age


age=df['Age'].mean()
age
# Out:
# 55.67215568862275

# %%
#computing the median on age


df['Age'].median()
# Out:
# 60.0

# %%
#checking for missing values in dataframe


df.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
#filling missing values for age column
df['Age'].fillna(age)
# Out:
# 0       23.000000
# 1       23.000000
# 2       24.000000
# 3       26.000000
# 4       30.000000
#           ...
# 1431    55.672156
# 1432    72.000000
# 1433    55.672156
# 1434    70.000000
# 1435    76.000000
# Name: Age, Length: 1436, dtype: float64

# %%
age=round(df['Age'].mean(),0)
age
# Out:
# 56.0

# %%
df['Age']=df['Age'].fillna(age)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
#computing the median on age


km_median=df['KM'].median()
km_median
# Out:
# 63634.0

# %%
#replacing the missing value with the median
df['KM']=df['KM'].fillna(km_median)

# %%
#checking for the missing values

df['KM'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # replacing missing values with categorical column

# %%
#cheching for missing values in fuel type
#computing the frequency of the fuel type
df['FuelType'].value_counts()
# Out:
# FuelType
# Petrol    1177
# Diesel     144
# CNG         15
# Name: count, dtype: int64

# %%
#select the highest value which is petrol using the index[]
df['FuelType'].value_counts().index[0]
# Out:
# 'Petrol'

# %%
highest_count_fuelType=df['FuelType'].value_counts().index[0]
highest_count_fuelType
# Out:
# 'Petrol'

# %%
#replacing the missing value with petrol

df['FuelType']=df['FuelType'].fillna(highest_count_fuelType)

# %%
df['FuelType'].isnull().sum()
# Out:
# 0

# %%
#changing the variable type using (astype)

df["MetColor"] =df["MetColor"].astype('category')

# %%
#chech for the highest value

df["MetColor"].value_counts()
# Out:
# MetColor
# 1.0    868
# 0.0    418
# Name: count, dtype: int64

# %%
#select the highest value 

MetColor_count=df["MetColor"].value_counts().index[0]
MetColor_count
# Out:
# 1.0

# %%
#replacing the missing values with the highest value

df["MetColor"] =df["MetColor"].fillna(MetColor_count)

# %%
df['MetColor'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       Price   Age       KM FuelType   HP MetColor  Automatic    CC Doors  \
# 0     13500  23.0  46986.0   Diesel   90      1.0          0  2000     3
# 1     13750  23.0  72937.0   Diesel   90      1.0          0  2000     3
# 2     13950  24.0  41711.0   Diesel   90      1.0          0  2000     3
# 3     14950  26.0  48000.0   Diesel   90      0.0          0  2000     3
# 4     13750  30.0  38500.0   Diesel   90      0.0          0  2000     3
# ...     ...   ...      ...      ...  ...      ...        ...   ...   ...
# 1431   7500  56.0  20544.0   Petrol   86      1.0          0  1300     3
# 1432  10845  72.0  63634.0   Petrol   86      0.0          0  1300     3
# 1433   8500  56.0  17016.0   Petrol   86      0.0          0  1300     3
# 1434   7250  70.0  63634.0   Petrol   86      1.0          0  1300     3
# 1435   6950  76.0      1.0   Petrol  110      0.0          0  1600     5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
#adding a column to dataframe

df['profit']=df['Price']-df['KM']

# %%
df
# Out:
#       Price   Age       KM FuelType   HP MetColor  Automatic    CC Doors  \
# 0     13500  23.0  46986.0   Diesel   90      1.0          0  2000     3
# 1     13750  23.0  72937.0   Diesel   90      1.0          0  2000     3
# 2     13950  24.0  41711.0   Diesel   90      1.0          0  2000     3
# 3     14950  26.0  48000.0   Diesel   90      0.0          0  2000     3
# 4     13750  30.0  38500.0   Diesel   90      0.0          0  2000     3
# ...     ...   ...      ...      ...  ...      ...        ...   ...   ...
# 1431   7500  56.0  20544.0   Petrol   86      1.0          0  1300     3
# 1432  10845  72.0  63634.0   Petrol   86      0.0          0  1300     3
# 1433   8500  56.0  17016.0   Petrol   86      0.0          0  1300     3
# 1434   7250  70.0  63634.0   Petrol   86      1.0          0  1300     3
# 1435   6950  76.0      1.0   Petrol  110      0.0          0  1600     5
#
#       Weight   profit
# 0       1165 -33486.0
# 1       1165 -59187.0
# ...

# %%
df.dtypes
# Out:
# Price           int64
# Age           float64
# KM            float64
# FuelType       object
# HP             object
# MetColor     category
# Automatic       int64
# CC              int64
# Doors          object
# Weight          int64
# profit        float64
# dtype: object

# %% [markdown]
# # Grouping of data

# %%
#Grouping of data into numerical 

numerical_col=['Price', 'Age','KM','HP','CC', 'Weight', 'profit']

# %%
df[numerical_col]
# Out:
#       Price   Age       KM   HP    CC  Weight   profit
# 0     13500  23.0  46986.0   90  2000    1165 -33486.0
# 1     13750  23.0  72937.0   90  2000    1165 -59187.0
# 2     13950  24.0  41711.0   90  2000    1165 -27761.0
# 3     14950  26.0  48000.0   90  2000    1165 -33050.0
# 4     13750  30.0  38500.0   90  2000    1170 -24750.0
# ...     ...   ...      ...  ...   ...     ...      ...
# 1431   7500  56.0  20544.0   86  1300    1025 -13044.0
# 1432  10845  72.0  63634.0   86  1300    1015 -52789.0
# 1433   8500  56.0  17016.0   86  1300    1015  -8516.0
# 1434   7250  70.0  63634.0   86  1300    1015 -56384.0
# 1435   6950  76.0      1.0  110  1600    1114   6949.0
#
# [1436 rows x 7 columns]

# %%
#grouping to categorical data

categorical_col=['Doors', 'FuelType', 'MetColor']

# %%
df[categorical_col]
# Out:
#      Doors FuelType MetColor
# 0        3   Diesel      1.0
# 1        3   Diesel      1.0
# 2        3   Diesel      1.0
# 3        3   Diesel      0.0
# 4        3   Diesel      0.0
# ...    ...      ...      ...
# 1431     3   Petrol      1.0
# 1432     3   Petrol      0.0
# 1433     3   Petrol      0.0
# 1434     3   Petrol      1.0
# 1435     5   Petrol      0.0
#
# [1436 rows x 3 columns]

# %%
cat_cals=['MetColor', 'Automatic', 'Doors']
num_cals=['Price', 'Age','KM','CC','Weight']

# %%
cat_df=df[cat_cals]
cat_num_df=df[num_cals]

# %% [markdown]
# # descrptive analysis
# - Total price
# - highest price
# - lowest price

# %%
#coputing the total price

df['Price'].sum()
# Out:
# 15409464

# %%
#computing the highest price

df['Price'].max()
# Out:
# 32500

# %%
#computing the lowest price

df['Price'].min()
# Out:
# 4350

# %%
# Using the describe()

df.describe().round()
# Out:
#          Price     Age        KM  Automatic      CC  Weight    profit
# count   1436.0  1436.0    1436.0     1436.0  1436.0  1436.0    1436.0
# mean   10731.0    56.0   68595.0        0.0  1567.0  1072.0  -57864.0
# std     3627.0    18.0   37141.0        0.0   187.0    53.0   39307.0
# min     4350.0     1.0       1.0        0.0  1300.0  1000.0 -236050.0
# 25%     8450.0    44.0   43506.0        0.0  1400.0  1040.0  -77603.0
# 50%     9900.0    59.0   63634.0        0.0  1600.0  1070.0  -53560.0
# 75%    11950.0    68.0   86916.0        0.0  1600.0  1085.0  -32013.0
# max    32500.0    80.0  243000.0        1.0  2000.0  1615.0   32499.0

# %%
# computing the correlation 
corr_df= cat_num_df.corr()
corr_df
# Out:
#            Price       Age        KM        CC    Weight
# Price   1.000000 -0.845194 -0.565926  0.165067  0.581198
# Age    -0.845194  1.000000  0.495496 -0.116375 -0.442166
# KM     -0.565926  0.495496  1.000000  0.296305 -0.026476
# CC      0.165067 -0.116375  0.296305  1.000000  0.651450
# Weight  0.581198 -0.442166 -0.026476  0.651450  1.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
#ploting a correlation graph for age and price (c='red')

plt.scatter(df['Age'],df['Price'], c='red')

# %%
#changing the title for your graph

plt.title('Relation between Age and Price of a car')
# Out:
# Text(0.5, 1.0, 'Relation between Age and Price of a car')

# %%
#changing the lable for y-axixs

plt.ylabel('Price(Dollar)')
# Out:
# Text(0, 0.5, 'Price(Dollar)')

# %%
#changing the lable for x-axixs

plt.xlabel('Age(Month)')
# Out:
# Text(0.5, 0, 'Age(Month)')

# %%
plt.savefig('age_price_rel.png')

# %%
plt.show()
